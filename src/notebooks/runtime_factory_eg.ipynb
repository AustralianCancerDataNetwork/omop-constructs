# %%
from omop_semantics.utils.load import load
from omop_constructs.factories.measurements import measurement_mv_factory
from omop_constructs.core.registry import ConstructRegistry

semantics = load(
    schema_paths=[...],
    instance_paths=[...],
)

measurement_views = measurement_mv_factory(
    registry=semantics,
    role="measurement",
)

registry = ConstructRegistry(measurement_views)

registry.create_all(engine)
registry.refresh_all(engine)

# %%
# views = measurement_mv_factory(
#     registry=semantics_registry,
#     role="measurement",
# )

# ConstructRegistry(views).create_all(engine)
